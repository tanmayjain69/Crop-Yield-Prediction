# %% [markdown]
# #Drive Mounting

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# #**CROP YIELD PREDICTION**

# %% [markdown]
# #Dataset 1

# %% [markdown]
# ##Reading Dataset

# %%
import pandas as pd
df = pd.read_csv('/content/drive/My Drive/Bennet/apy.csv', encoding='utf-8')
df
# Out:
#                          State_Name District_Name  ...  Production     Yield
# 0       Andaman and Nicobar Islands      NICOBARS  ...      2000.0  1.594896
# 1       Andaman and Nicobar Islands      NICOBARS  ...         1.0  0.500000
# 2       Andaman and Nicobar Islands      NICOBARS  ...       321.0  3.147059
# 3       Andaman and Nicobar Islands      NICOBARS  ...       641.0  3.642045
# 4       Andaman and Nicobar Islands      NICOBARS  ...       165.0  0.229167
# ...                             ...           ...  ...         ...       ...
# 246086                  West Bengal       PURULIA  ...       801.0       NaN
# 246087                  West Bengal       PURULIA  ...       463.0       NaN
# 246088                  West Bengal       PURULIA  ...     16250.0       NaN
# 246089                  West Bengal       PURULIA  ...    597899.0       NaN
# 246090                  West Bengal       PURULIA  ...        88.0       NaN
#
# [246091 rows x 8 columns]

# %% [markdown]
# ##Reducing Data to One State for Ease

# %%
df = df[df['State_Name'] == "Andhra Pradesh"]

# %% [markdown]
# ###Making Yield Column

# %%
df['Yield'] = df['Production']/df['Area']
df
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#           State_Name  District_Name  ...   Production         Yield
# 203   Andhra Pradesh      ANANTAPUR  ...       2600.0      0.121495
# 204   Andhra Pradesh      ANANTAPUR  ...        500.0      0.357143
# 205   Andhra Pradesh      ANANTAPUR  ...        100.0      0.100000
# 206   Andhra Pradesh      ANANTAPUR  ...       9400.0      1.287671
# 207   Andhra Pradesh      ANANTAPUR  ...       7100.0      1.918919
# ...              ...            ...  ...          ...           ...
# 9826  Andhra Pradesh  WEST GODAVARI  ...      89107.0      3.177173
# 9827  Andhra Pradesh  WEST GODAVARI  ...       3035.0     13.549107
# 9828  Andhra Pradesh  WEST GODAVARI  ...       4833.0      0.892027
# 9829  Andhra Pradesh  WEST GODAVARI  ...  718991000.0  33089.005477
# 9830  Andhra Pradesh  WEST GODAVARI  ...    1624324.0      3.968677
#
# [9628 rows x 8 columns]

# %% [markdown]
# ##Corelation Heatmap

# %%
import matplotlib.pyplot as plt
import seaborn as sb

C_mat = df.corr()
fig = plt.figure(figsize = (15,15))

sb.heatmap(C_mat, vmax = .8, square = True)
plt.show()

# %% [markdown]
# ##Taking Data only after 2004

# %%
df = df[df['Crop_Year']>=2004]
df
# Out:
#           State_Name  District_Name  ...   Production         Yield
# 493   Andhra Pradesh      ANANTAPUR  ...       7893.0      0.240993
# 494   Andhra Pradesh      ANANTAPUR  ...        403.0      0.394711
# 495   Andhra Pradesh      ANANTAPUR  ...        923.0      0.584918
# 496   Andhra Pradesh      ANANTAPUR  ...       7041.0      0.788201
# 497   Andhra Pradesh      ANANTAPUR  ...      11288.0      3.318048
# ...              ...            ...  ...          ...           ...
# 9826  Andhra Pradesh  WEST GODAVARI  ...      89107.0      3.177173
# 9827  Andhra Pradesh  WEST GODAVARI  ...       3035.0     13.549107
# 9828  Andhra Pradesh  WEST GODAVARI  ...       4833.0      0.892027
# 9829  Andhra Pradesh  WEST GODAVARI  ...  718991000.0  33089.005477
# 9830  Andhra Pradesh  WEST GODAVARI  ...    1624324.0      3.968677
#
# [5999 rows x 8 columns]

# %% [markdown]
# ##Encoding All Categorical Data

# %%
df = df.join(pd.get_dummies(df['District_Name']))
df = df.join(pd.get_dummies(df['Season']))
df = df.join(pd.get_dummies(df['Crop']))
df = df.join(pd.get_dummies(df['Crop_Year']))
df = df.join(pd.get_dummies(df['State_Name']))
df
# Out:
#           State_Name  District_Name  Crop_Year  ... 2013 2014  Andhra Pradesh
# 493   Andhra Pradesh      ANANTAPUR       2004  ...    0    0               1
# 494   Andhra Pradesh      ANANTAPUR       2004  ...    0    0               1
# 495   Andhra Pradesh      ANANTAPUR       2004  ...    0    0               1
# 496   Andhra Pradesh      ANANTAPUR       2004  ...    0    0               1
# 497   Andhra Pradesh      ANANTAPUR       2004  ...    0    0               1
# ...              ...            ...        ...  ...  ...  ...             ...
# 9826  Andhra Pradesh  WEST GODAVARI       2014  ...    0    1               1
# 9827  Andhra Pradesh  WEST GODAVARI       2014  ...    0    1               1
# 9828  Andhra Pradesh  WEST GODAVARI       2014  ...    0    1               1
# 9829  Andhra Pradesh  WEST GODAVARI       2014  ...    0    1               1
# 9830  Andhra Pradesh  WEST GODAVARI       2014  ...    0    1               1
#
# [5999 rows x 89 columns]

# %% [markdown]
# ##Dropping Unecessory Columns

# %%
df=df.drop('District_Name', axis=1)
df = df.drop('Season',axis=1)
df = df.drop('Crop',axis=1)
df = df.drop('Crop_Year', axis=1)
df = df.drop('Production', axis=1)
df = df.drop('State_Name', axis=1)
df
# Out:
#           Area         Yield  ANANTAPUR  ...  2013  2014  Andhra Pradesh
# 493    32752.0      0.240993          1  ...     0     0               1
# 494     1021.0      0.394711          1  ...     0     0               1
# 495     1578.0      0.584918          1  ...     0     0               1
# 496     8933.0      0.788201          1  ...     0     0               1
# 497     3402.0      3.318048          1  ...     0     0               1
# ...        ...           ...        ...  ...   ...   ...             ...
# 9826   28046.0      3.177173          0  ...     0     1               1
# 9827     224.0     13.549107          0  ...     0     1               1
# 9828    5418.0      0.892027          0  ...     0     1               1
# 9829   21729.0  33089.005477          0  ...     0     1               1
# 9830  409286.0      3.968677          0  ...     0     1               1
#
# [5999 rows x 83 columns]

# %% [markdown]
# ##Preprocessing

# %%
from sklearn import preprocessing

# %%
# Create x, where x the 'scores' column's values as floats
x = df[['Area']].values.astype(float)
x
# Create a minimum and maximum processor object
min_max_scaler = preprocessing.MinMaxScaler()

# Create an object to transform the data to fit minmax processor
x_scaled = min_max_scaler.fit_transform(x)

# Run the normalizer on the dataframe
#df_normalized = pd.DataFrame(x_scaled)
x_scaled

df['Area'] = x_scaled
df
# Out:
#           Area         Yield  ANANTAPUR  ...  2013  2014  Andhra Pradesh
# 493   0.037343      0.240993          1  ...     0     0               1
# 494   0.001163      0.394711          1  ...     0     0               1
# 495   0.001798      0.584918          1  ...     0     0               1
# 496   0.010184      0.788201          1  ...     0     0               1
# 497   0.003878      3.318048          1  ...     0     0               1
# ...        ...           ...        ...  ...   ...   ...             ...
# 9826  0.031977      3.177173          0  ...     0     1               1
# 9827  0.000254     13.549107          0  ...     0     1               1
# 9828  0.006177      0.892027          0  ...     0     1               1
# 9829  0.024775  33089.005477          0  ...     0     1               1
# 9830  0.466673      3.968677          0  ...     0     1               1
#
# [5999 rows x 83 columns]

# %%
df.head()
# Out:
#          Area     Yield  ANANTAPUR  CHITTOOR  ...  2012  2013  2014  Andhra Pradesh
# 493  0.037343  0.240993          1         0  ...     0     0     0               1
# 494  0.001163  0.394711          1         0  ...     0     0     0               1
# 495  0.001798  0.584918          1         0  ...     0     0     0               1
# 496  0.010184  0.788201          1         0  ...     0     0     0               1
# 497  0.003878  3.318048          1         0  ...     0     0     0               1
#
# [5 rows x 83 columns]

# %% [markdown]
# ### Filling Empty Values With Mean

# %%
df = df.fillna(df.mean())

# %% [markdown]
# ##Train and Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
b = df['Yield']
a = df.drop('Yield', axis = 1)

a_train, a_test, b_train, b_test = train_test_split(a, b, test_size = 0.3, random_state = 42)

print(a_train)
print(a_test)
print(b_train)
print(b_test)
# Out:
#           Area  ANANTAPUR  CHITTOOR  ...  2013  2014  Andhra Pradesh
# 1711  0.000246          0         1  ...     1     0               1
# 5452  0.031408          0         0  ...     1     0               1
# 538   0.003756          1         0  ...     0     0               1
# 2336  0.014880          0         0  ...     0     0               1
# 2172  0.001397          0         0  ...     0     0               1
# ...        ...        ...       ...  ...   ...   ...             ...
# 6278  0.001999          0         0  ...     0     1               1
# 8796  0.000129          0         0  ...     0     0               1
# 8831  0.000385          0         0  ...     0     0               1
# 8995  0.000344          0         0  ...     0     0               1
# 1644  0.000268          0         1  ...     0     0               1
#
# [4199 rows x 82 columns]
#           Area  ANANTAPUR  CHITTOOR  ...  2013  2014  Andhra Pradesh
# 577   0.000706          1         0  ...     0     0               1
# 4044  0.000341          0         0  ...     0     1               1
# 8328  0.000667          0         0  ...     0     0               1
# 839   0.002276          1         0  ...     0     0               1
# 572   0.055501          1         0  ...     0     0               1
# ...        ...        ...       ...  ...   ...   ...             ...
# 1625  0.000011          0         1  ...     0     0               1
# 4457  0.000047          0         0  ...     0     0               1
# 2265  0.000426          0         0  ...     0     0               1
# 668   0.048193          1         0  ...     0     0               1
# 3867  0.000472          0         0  ...     0     0               1
#
# [1800 rows x 82 columns]
# 1711    11.741935
# 5452     0.469997
# 538      1.047041
# 2336    83.248104
# 2172     0.256117
#           ...
# 6278     6.176169
# 8796    16.964912
# 8831     0.554572
# 8995    25.392739
# 1644     0.673729
# Name: Yield, Length: 4199, dtype: float64
# 577     0.304839
# 4044    0.310000
# 8328    2.470990
# 839     0.661993
# 572     0.172587
#           ...
# 1625    1.818182
# 4457    1.023810
# 2265    0.765333
# 668     0.622338
# 3867    0.481928
# Name: Yield, Length: 1800, dtype: float64

# %%
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
a_train = sc.fit_transform(a_train)
a_test = sc.transform(a_test)

# %% [markdown]
# ###Random Forest Regressor

# %%
   from sklearn.ensemble import RandomForestRegressor
   regr = RandomForestRegressor(max_depth=2, random_state=0, n_estimators=100)
   regr.fit(a_train, b_train)
   b_pred = regr.predict(a_test)

   from sklearn.metrics import mean_squared_error as mse
   from sklearn.metrics import mean_absolute_error as mae
   from sklearn.metrics import r2_score

   print('MSE =', mse(b_pred, b_test))
   print('MAE =', mae(b_pred, b_test))
   print('R2 Score =', r2_score(b_pred, b_test))
# Out:
# MSE = 344244.0619993072
# MAE = 79.0739528510798
# R2 Score = 0.8897409726497765

# %% [markdown]
# ###Polynomial Support Vector Machine

# %%
from sklearn.svm import SVR
regressorpoly=SVR(kernel='poly',epsilon=1.0)
regressorpoly.fit(a_train,b_train)
pred=regressorpoly.predict(a_test)
print(regressorpoly.score(a_test,b_test))
print(r2_score(b_test,b_pred))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# -0.014337696667276136
# 0.8863535872418126

# %% [markdown]
# ###XGBRegressor

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error 
XGBModel = XGBRegressor()
XGBModel.fit(a_train,b_train , verbose=False)

# Get the mean absolute error on the validation data :
XGBpredictions = XGBModel.predict(a_test)
MAE = mean_absolute_error(b_test , XGBpredictions)
print('XGBoost validation MAE = ',MAE)
XGBpredictions
# Out:
# [06:37:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# XGBoost validation MAE =  49.870773418945774
# array([5.5103283, 5.0048275, 5.0821667, ..., 4.9217033, 3.30962  ,
#        5.3301153], dtype=float32)

# %% [markdown]
# ##Neural Network Implementation

# %%
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from matplotlib import pyplot as plt
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings
from keras.callbacks import History 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = a_train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4409: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               10624
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 175,489
# Trainable params: 175,489
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import History 
history = History()
History=NN_model.fit(a_train, b_train, epochs=50, batch_size=500, validation_split = 0.2, callbacks=[history])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 3359 samples, validate on 840 samples
# Epoch 1/50
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 3359/3359 [==============================] - 1s 303us/step - loss: 233.5214 - mean_absolute_error: 233.5214 - val_loss: 219.5405 - val_mean_absolute_error: 219.5405
# Epoch 2/50
# 3359/3359 [==============================] - 0s 14us/step - loss: 233.0385 - mean_absolute_error: 233.0385 - val_loss: 219.2049 - val_mean_absolute_error: 219.2049
# Epoch 3/50
# 3359/3359 [==============================] - 0s 15us/step - loss: 232.5677 - mean_absolute_error: 232.5677 - val_loss: 218.6326 - val_mean_absolute_error: 218.6326
# Epoch 4/50
# 3359/3359 [==============================] - 0s 15us/step - loss: 231.8598 - mean_absolute_error: 231.8598 - val_loss: 217.7789 - val_mean_absolute_error: 217.7789
# Epoch 5/50
# 3359/3359 [==============================] - 0s 13us/step - loss: 230.9909 - mean_absolute_error: 230.9909 - val_loss: 216.8283 - val_mean_absolute_error: 216.8283
# Epoch 6/50
# 3359/3359 [==============================] - 0s 15us/step - loss: 230.1301 - mean_absolute_error: 230.1301 - val_loss: 215.8665 - val_mean_absolute_error: 215.8665
# Epoch 7/50
# 3359/3359 [==============================] - 0s 15us/step - loss: 229.1218 - mean_absolute_error: 229.1218 - val_loss: 214.6328 - val_mean_absolute_error: 214.6328
# Epoch 8/50
# 3359/3359 [==============================] - 0s 13us/step - loss: 227.5034 - mean_absolute_error: 227.5034 - val_loss: 213.4591 - val_mean_absolute_error: 213.4591
# Epoch 9/50
# 3359/3359 [==============================] - 0s 14us/step - loss: 226.3727 - mean_absolute_error: 226.3727 - val_loss: 212.0167 - val_mean_absolute_error: 212.0167
# Epoch 10/50
# 3359/3359 [==============================] - 0s 16us/step - loss: 224.3176 - mean_absolute_error: 224.3176 - val_loss: 209.9144 - val_mean_absolute_error: 209.9144
# Epoch 11/50
# 3359/3359 [==============================] - 0s 17us/step - loss: 219.6201 - mean_absolute_error: 219.6201 - val_loss: 204.6155 - val_mean_absolute_error: 204.6155
# Epoch 12/50
# 3359/3359 [==============================] - 0s 15us/step - loss: 207.5196 - mean_absolute_error: 207.5196 - val_loss: 187.3352 - val_mean_absolute_error: 187.3352
# Epoch 13/50
# 3359/3359 [==============================] - 0s 14us/step - loss: 172.3908 - mean_absolute_error: 172.3908 - val_loss: 143.1024 - val_mean_absolute_error: 143.1024
# Epoch 14/50
# 3359/3359 [==============================] - 0s 14us/step - loss: 95.7524 - mean_absolute_error: 95.7524 - val_loss: 79.2580 - val_mean_absolute_error: 79.2580
# Epoch 15/50
# 3359/3359 [==============================] - 0s 14us/step - loss: 81.7212 - mean_absolute_error: 81.7212 - val_loss: 75.3563 - val_mean_absolute_error: 75.3563
# Epoch 16/50
# 3359/3359 [==============================] - 0s 15us/step - loss: 70.8952 - mean_absolute_error: 70.8952 - val_loss: 80.7395 - val_mean_absolute_error: 80.7395
# Epoch 17/50
# 3359/3359 [==============================] - 0s 16us/step - loss: 66.2102 - mean_absolute_error: 66.2102 - val_loss: 76.7014 - val_mean_absolute_error: 76.7014
# Epoch 18/50
# 3359/3359 [==============================] - 0s 14us/step - loss: 61.7440 - mean_absolute_error: 61.7440 - val_loss: 72.1441 - val_mean_absolute_error: 72.1441
# Epoch 19/50
# 3359/3359 [==============================] - 0s 14us/step - loss: 58.8156 - mean_absolute_error: 58.8156 - val_loss: 69.2405 - val_mean_absolute_error: 69.2405
# Epoch 20/50
# 3359/3359 [==============================] - 0s 14us/step - loss: 56.2616 - mean_absolute_error: 56.2616 - val_loss: 58.5533 - val_mean_absolute_error: 58.5533
# Epoch 21/50
# 3359/3359 [==============================] - 0s 14us/step - loss: 52.7188 - mean_absolute_error: 52.7188 - val_loss: 67.6081 - val_mean_absolute_error: 67.6081
# Epoch 22/50
# 3359/3359 [==============================] - 0s 15us/step - loss: 49.8450 - mean_absolute_error: 49.8450 - val_loss: 51.8421 - val_mean_absolute_error: 51.8421
# Epoch 23/50
# 3359/3359 [==============================] - 0s 15us/step - loss: 48.4614 - mean_absolute_error: 48.4614 - val_loss: 45.9759 - val_mean_absolute_error: 45.9759
# Epoch 24/50
# 3359/3359 [==============================] - 0s 15us/step - loss: 43.8657 - mean_absolute_error: 43.8657 - val_loss: 56.7690 - val_mean_absolute_error: 56.7690
# Epoch 25/50
# 3359/3359 [==============================] - 0s 14us/step - loss: 39.3394 - mean_absolute_error: 39.3394 - val_loss: 40.2429 - val_mean_absolute_error: 40.2429
# Epoch 26/50
# 3359/3359 [==============================] - 0s 15us/step - loss: 43.0837 - mean_absolute_error: 43.0837 - val_loss: 43.7615 - val_mean_absolute_error: 43.7615
# Epoch 27/50
# 3359/3359 [==============================] - 0s 15us/step - loss: 43.9940 - mean_absolute_error: 43.9940 - val_loss: 48.1536 - val_mean_absolute_error: 48.1536
# Epoch 28/50
# 3359/3359 [==============================] - 0s 14us/step - loss: 37.8546 - mean_absolute_error: 37.8546 - val_loss: 37.1469 - val_mean_absolute_error: 37.1469
# Epoch 29/50
# 3359/3359 [==============================] - 0s 14us/step - loss: 36.2285 - mean_absolute_error: 36.2285 - val_loss: 39.2863 - val_mean_absolute_error: 39.2863
# Epoch 30/50
# 3359/3359 [==============================] - 0s 14us/step - loss: 35.5116 - mean_absolute_error: 35.5116 - val_loss: 35.6967 - val_mean_absolute_error: 35.6967
# Epoch 31/50
# 3359/3359 [==============================] - 0s 16us/step - loss: 34.9196 - mean_absolute_error: 34.9196 - val_loss: 36.8786 - val_mean_absolute_error: 36.8786
# Epoch 32/50
# 3359/3359 [==============================] - 0s 16us/step - loss: 35.2890 - mean_absolute_error: 35.2890 - val_loss: 35.2010 - val_mean_absolute_error: 35.2010
# Epoch 33/50
# 3359/3359 [==============================] - 0s 15us/step - loss: 34.3200 - mean_absolute_error: 34.3200 - val_loss: 35.7966 - val_mean_absolute_error: 35.7966
# Epoch 34/50
# 3359/3359 [==============================] - 0s 14us/step - loss: 31.1346 - mean_absolute_error: 31.1346 - val_loss: 35.5697 - val_mean_absolute_error: 35.5697
# Epoch 35/50
# 3359/3359 [==============================] - 0s 15us/step - loss: 29.7315 - mean_absolute_error: 29.7315 - val_loss: 32.6138 - val_mean_absolute_error: 32.6138
# Epoch 36/50
# 3359/3359 [==============================] - 0s 15us/step - loss: 28.5257 - mean_absolute_error: 28.5257 - val_loss: 28.6778 - val_mean_absolute_error: 28.6778
# Epoch 37/50
# 3359/3359 [==============================] - 0s 15us/step - loss: 28.1673 - mean_absolute_error: 28.1673 - val_loss: 29.9256 - val_mean_absolute_error: 29.9256
# Epoch 38/50
# 3359/3359 [==============================] - 0s 14us/step - loss: 26.4070 - mean_absolute_error: 26.4070 - val_loss: 31.8909 - val_mean_absolute_error: 31.8909
# Epoch 39/50
# 3359/3359 [==============================] - 0s 14us/step - loss: 24.6948 - mean_absolute_error: 24.6948 - val_loss: 27.7855 - val_mean_absolute_error: 27.7855
# Epoch 40/50
# 3359/3359 [==============================] - 0s 16us/step - loss: 26.0862 - mean_absolute_error: 26.0862 - val_loss: 34.3586 - val_mean_absolute_error: 34.3586
# Epoch 41/50
# 3359/3359 [==============================] - 0s 15us/step - loss: 24.1266 - mean_absolute_error: 24.1266 - val_loss: 34.3061 - val_mean_absolute_error: 34.3061
# Epoch 42/50
# 3359/3359 [==============================] - 0s 15us/step - loss: 23.4039 - mean_absolute_error: 23.4039 - val_loss: 29.3812 - val_mean_absolute_error: 29.3812
# Epoch 43/50
# 3359/3359 [==============================] - 0s 16us/step - loss: 21.3739 - mean_absolute_error: 21.3739 - val_loss: 34.1644 - val_mean_absolute_error: 34.1644
# Epoch 44/50
# 3359/3359 [==============================] - 0s 15us/step - loss: 20.2977 - mean_absolute_error: 20.2977 - val_loss: 34.2045 - val_mean_absolute_error: 34.2045
# Epoch 45/50
# 3359/3359 [==============================] - 0s 15us/step - loss: 20.3740 - mean_absolute_error: 20.3740 - val_loss: 28.9777 - val_mean_absolute_error: 28.9777
# Epoch 46/50
# 3359/3359 [==============================] - 0s 14us/step - loss: 23.4038 - mean_absolute_error: 23.4038 - val_loss: 36.3724 - val_mean_absolute_error: 36.3724
# Epoch 47/50
# 3359/3359 [==============================] - 0s 15us/step - loss: 20.1131 - mean_absolute_error: 20.1131 - val_loss: 31.3809 - val_mean_absolute_error: 31.3809
# Epoch 48/50
# 3359/3359 [==============================] - 0s 15us/step - loss: 20.1179 - mean_absolute_error: 20.1179 - val_loss: 31.4443 - val_mean_absolute_error: 31.4443
# Epoch 49/50
# 3359/3359 [==============================] - 0s 15us/step - loss: 17.2411 - mean_absolute_error: 17.2411 - val_loss: 30.8612 - val_mean_absolute_error: 30.8612
# Epoch 50/50
# 3359/3359 [==============================] - 0s 15us/step - loss: 16.9319 - mean_absolute_error: 16.9319 - val_loss: 33.2599 - val_mean_absolute_error: 33.2599

# %%
print(history.history.keys())
plt.plot(History.history['mean_absolute_error'])
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_error', 'loss', 'mean_absolute_error'])
# Text(0.5, 0, 'epoch')

# %%
plt.plot(History.history['mean_absolute_error'])
plt.plot(History.history['val_mean_absolute_error'])
plt.title('mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
 # summarize history for loss
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# #Dataset 2

# %% [markdown]
# ##Reading Dataset

# %%
import pandas as pd
df2 = pd.read_csv('/content/drive/My Drive/Bennet/wheat-2014-supervised.csv', encoding='utf-8')
df2
# Out:
#        CountyName       State   Latitude  ...        NDVI DayInSeason  Yield
# 0           Adams  Washington  46.929839  ...  136.179718           0   35.6
# 1           Adams  Washington  47.150327  ...  135.697540           0   35.6
# 2           Adams  Washington  46.811686  ...  135.676956           0   35.6
# 3           Adams  Washington  47.162342  ...  135.005798           0   35.6
# 4           Adams  Washington  47.157512  ...  134.803864           0   35.6
# ...           ...         ...        ...  ...         ...         ...    ...
# 182544      Miami      Kansas  38.693595  ...  134.803101         185   50.1
# 182545      Miami      Kansas  38.603699  ...  133.913879         185   50.1
# 182546      Miami      Kansas  38.580826  ...  129.938950         185   50.1
# 182547      Miami      Kansas  38.564866  ...  129.938950         185   50.1
# 182548      Miami      Kansas  38.392008  ...  129.784332         185   50.1
#
# [182549 rows x 26 columns]

# %%
df2.dtypes
# Out:
# CountyName                 object
# State                      object
# Latitude                  float64
# Longitude                 float64
# Date                       object
# apparentTemperatureMax    float64
# apparentTemperatureMin    float64
# cloudCover                float64
# dewPoint                  float64
# humidity                  float64
# precipIntensity           float64
# precipIntensityMax        float64
# precipProbability         float64
# precipAccumulation        float64
# precipTypeIsRain            int64
# precipTypeIsSnow            int64
# precipTypeIsOther           int64
# pressure                  float64
# temperatureMax            float64
# temperatureMin            float64
# visibility                float64
# windBearing                 int64
# windSpeed                 float64
# NDVI                      float64
# DayInSeason                 int64
# Yield                     float64
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sb


C_mat = df2.corr()
fig = plt.figure(figsize = (15,15))

sb.heatmap(C_mat, vmax = .8, square = True)
plt.show()

# %%
df2 = df2.drop('CountyName', axis=1)
df2 = df2.drop('State', axis=1)
df2 = df2.drop('Date', axis=1)
df2 = df2.drop('precipTypeIsOther', axis=1)
df2
# Out:
#          Latitude   Longitude  ...  DayInSeason  Yield
# 0       46.929839 -118.352109  ...            0   35.6
# 1       47.150327 -118.958859  ...            0   35.6
# 2       46.811686 -118.695237  ...            0   35.6
# 3       47.162342 -118.699677  ...            0   35.6
# 4       47.157512 -118.434056  ...            0   35.6
# ...           ...         ...  ...          ...    ...
# 182544  38.693595  -94.671846  ...          185   50.1
# 182545  38.603699  -94.992247  ...          185   50.1
# 182546  38.580826  -94.794660  ...          185   50.1
# 182547  38.564866  -94.748021  ...          185   50.1
# 182548  38.392008  -94.855430  ...          185   50.1
#
# [182549 rows x 22 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sb

C_mat = df2.corr()
fig = plt.figure(figsize = (15,15))

sb.heatmap(C_mat, vmax = .8, square = True)
plt.show()

# %%
df2 = df2.fillna(df2.mean())
df2
# Out:
#          Latitude   Longitude  ...  DayInSeason  Yield
# 0       46.929839 -118.352109  ...            0   35.6
# 1       47.150327 -118.958859  ...            0   35.6
# 2       46.811686 -118.695237  ...            0   35.6
# 3       47.162342 -118.699677  ...            0   35.6
# 4       47.157512 -118.434056  ...            0   35.6
# ...           ...         ...  ...          ...    ...
# 182544  38.693595  -94.671846  ...          185   50.1
# 182545  38.603699  -94.992247  ...          185   50.1
# 182546  38.580826  -94.794660  ...          185   50.1
# 182547  38.564866  -94.748021  ...          185   50.1
# 182548  38.392008  -94.855430  ...          185   50.1
#
# [182549 rows x 22 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
b1 = df2['Yield']
a1 = df2.drop('Yield', axis = 1)

a1_train, a1_test, b1_train, b1_test = train_test_split(a1, b1, test_size = 0.3, random_state = 42)

# %%
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
a1_train = sc.fit_transform(a1_train)
a1_test = sc.transform(a1_test)

# %%
from sklearn.ensemble import RandomForestRegressor
regr = RandomForestRegressor(max_depth=2, random_state=0, n_estimators=100)
regr.fit(a1_train, b1_train)
b1_pred = regr.predict(a1_test)
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import r2_score

print('MSE =', mse(b1_pred, b1_test))
print('MAE =', mae(b1_pred, b1_test))
print('R2 Score =', r2_score(b1_pred, b1_test))
# Out:
# MSE = 64.98646830324311
# MAE = 6.16041791367379
# R2 Score = -0.3557584820839037

# %%
from sklearn.svm import SVR
regressorpoly=SVR(kernel='poly',epsilon=1.3)
regressorpoly.fit(a_train,b_train)
pred=regressorpoly.predict(a_test)
print(regressorpoly.score(a_test,b_test))
print(r2_score(b_test,b_pred))
# Out:
# -0.014302280272882939
# 0.8863535872418126

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error 
XGBModel = XGBRegressor()
XGBModel.fit(a1_train,b1_train , verbose=True)

# Get the mean absolute error on the validation data :
XGBpredictions = XGBModel.predict(a1_test)
MAE = mean_absolute_error(b1_test , XGBpredictions)
print('XGBoost validation MAE = ',MAE)
XGBpredictions
# Out:
# [06:41:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBoost validation MAE =  3.6932588228538985
# array([26.139877, 33.78574 , 39.834476, ..., 33.21663 , 34.368736,
#        24.456388], dtype=float32)

# %%
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from matplotlib import pyplot as plt
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings
from keras.callbacks import History 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)

# %%
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = a_train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 128)               10624
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_11 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 307,073
# Trainable params: 307,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import History 
history = History()
History=NN_model.fit(a_train, b_train, epochs=50, batch_size=500, validation_split = 0.2, callbacks=[history])
# Out:
# Train on 3359 samples, validate on 840 samples
# Epoch 1/50
# 3359/3359 [==============================] - 1s 153us/step - loss: 233.5804 - mean_absolute_error: 233.5804 - val_loss: 219.5755 - val_mean_absolute_error: 219.5755
# Epoch 2/50
# 3359/3359 [==============================] - 0s 18us/step - loss: 233.0163 - mean_absolute_error: 233.0163 - val_loss: 219.2257 - val_mean_absolute_error: 219.2257
# Epoch 3/50
# 3359/3359 [==============================] - 0s 17us/step - loss: 232.5071 - mean_absolute_error: 232.5071 - val_loss: 218.4885 - val_mean_absolute_error: 218.4885
# Epoch 4/50
# 3359/3359 [==============================] - 0s 20us/step - loss: 231.6817 - mean_absolute_error: 231.6817 - val_loss: 217.4594 - val_mean_absolute_error: 217.4594
# Epoch 5/50
# 3359/3359 [==============================] - 0s 18us/step - loss: 230.5929 - mean_absolute_error: 230.5929 - val_loss: 216.0987 - val_mean_absolute_error: 216.0987
# Epoch 6/50
# 3359/3359 [==============================] - 0s 19us/step - loss: 229.0822 - mean_absolute_error: 229.0822 - val_loss: 213.9812 - val_mean_absolute_error: 213.9812
# Epoch 7/50
# 3359/3359 [==============================] - 0s 18us/step - loss: 226.5397 - mean_absolute_error: 226.5397 - val_loss: 212.1162 - val_mean_absolute_error: 212.1162
# Epoch 8/50
# 3359/3359 [==============================] - 0s 18us/step - loss: 221.3560 - mean_absolute_error: 221.3560 - val_loss: 199.5272 - val_mean_absolute_error: 199.5272
# Epoch 9/50
# 3359/3359 [==============================] - 0s 18us/step - loss: 179.3656 - mean_absolute_error: 179.3656 - val_loss: 116.1424 - val_mean_absolute_error: 116.1424
# Epoch 10/50
# 3359/3359 [==============================] - 0s 18us/step - loss: 94.5738 - mean_absolute_error: 94.5738 - val_loss: 70.8565 - val_mean_absolute_error: 70.8565
# Epoch 11/50
# 3359/3359 [==============================] - 0s 17us/step - loss: 78.2001 - mean_absolute_error: 78.2001 - val_loss: 106.2591 - val_mean_absolute_error: 106.2591
# Epoch 12/50
# 3359/3359 [==============================] - 0s 17us/step - loss: 71.7075 - mean_absolute_error: 71.7075 - val_loss: 63.2456 - val_mean_absolute_error: 63.2456
# Epoch 13/50
# 3359/3359 [==============================] - 0s 18us/step - loss: 70.7326 - mean_absolute_error: 70.7326 - val_loss: 72.1757 - val_mean_absolute_error: 72.1757
# Epoch 14/50
# 3359/3359 [==============================] - 0s 17us/step - loss: 58.9302 - mean_absolute_error: 58.9302 - val_loss: 56.5759 - val_mean_absolute_error: 56.5759
# Epoch 15/50
# 3359/3359 [==============================] - 0s 17us/step - loss: 49.4415 - mean_absolute_error: 49.4415 - val_loss: 48.8692 - val_mean_absolute_error: 48.8692
# Epoch 16/50
# 3359/3359 [==============================] - 0s 17us/step - loss: 45.3791 - mean_absolute_error: 45.3791 - val_loss: 48.5606 - val_mean_absolute_error: 48.5606
# Epoch 17/50
# 3359/3359 [==============================] - 0s 19us/step - loss: 40.6414 - mean_absolute_error: 40.6414 - val_loss: 45.1039 - val_mean_absolute_error: 45.1039
# Epoch 18/50
# 3359/3359 [==============================] - 0s 18us/step - loss: 39.0719 - mean_absolute_error: 39.0719 - val_loss: 36.0897 - val_mean_absolute_error: 36.0897
# Epoch 19/50
# 3359/3359 [==============================] - 0s 17us/step - loss: 40.5402 - mean_absolute_error: 40.5402 - val_loss: 52.2464 - val_mean_absolute_error: 52.2464
# Epoch 20/50
# 3359/3359 [==============================] - 0s 24us/step - loss: 38.8871 - mean_absolute_error: 38.8871 - val_loss: 42.0986 - val_mean_absolute_error: 42.0986
# Epoch 21/50
# 3359/3359 [==============================] - 0s 17us/step - loss: 37.5205 - mean_absolute_error: 37.5205 - val_loss: 36.0290 - val_mean_absolute_error: 36.0290
# Epoch 22/50
# 3359/3359 [==============================] - 0s 18us/step - loss: 36.2845 - mean_absolute_error: 36.2845 - val_loss: 44.0437 - val_mean_absolute_error: 44.0437
# Epoch 23/50
# 3359/3359 [==============================] - 0s 18us/step - loss: 32.3030 - mean_absolute_error: 32.3030 - val_loss: 36.4768 - val_mean_absolute_error: 36.4768
# Epoch 24/50
# 3359/3359 [==============================] - 0s 18us/step - loss: 35.8103 - mean_absolute_error: 35.8103 - val_loss: 34.4654 - val_mean_absolute_error: 34.4654
# Epoch 25/50
# 3359/3359 [==============================] - 0s 17us/step - loss: 32.6367 - mean_absolute_error: 32.6367 - val_loss: 34.1798 - val_mean_absolute_error: 34.1798
# Epoch 26/50
# 3359/3359 [==============================] - 0s 18us/step - loss: 28.2458 - mean_absolute_error: 28.2458 - val_loss: 31.5427 - val_mean_absolute_error: 31.5427
# Epoch 27/50
# 3359/3359 [==============================] - 0s 17us/step - loss: 25.4748 - mean_absolute_error: 25.4748 - val_loss: 33.5664 - val_mean_absolute_error: 33.5664
# Epoch 28/50
# 3359/3359 [==============================] - 0s 17us/step - loss: 25.7323 - mean_absolute_error: 25.7323 - val_loss: 33.0483 - val_mean_absolute_error: 33.0483
# Epoch 29/50
# 3359/3359 [==============================] - 0s 19us/step - loss: 24.1512 - mean_absolute_error: 24.1512 - val_loss: 30.2462 - val_mean_absolute_error: 30.2462
# Epoch 30/50
# 3359/3359 [==============================] - 0s 18us/step - loss: 26.4377 - mean_absolute_error: 26.4377 - val_loss: 36.6430 - val_mean_absolute_error: 36.6430
# Epoch 31/50
# 3359/3359 [==============================] - 0s 18us/step - loss: 22.1443 - mean_absolute_error: 22.1443 - val_loss: 28.6303 - val_mean_absolute_error: 28.6303
# Epoch 32/50
# 3359/3359 [==============================] - 0s 18us/step - loss: 19.0349 - mean_absolute_error: 19.0349 - val_loss: 30.9033 - val_mean_absolute_error: 30.9033
# Epoch 33/50
# 3359/3359 [==============================] - 0s 18us/step - loss: 19.0870 - mean_absolute_error: 19.0870 - val_loss: 29.7870 - val_mean_absolute_error: 29.7870
# Epoch 34/50
# 3359/3359 [==============================] - 0s 18us/step - loss: 20.1995 - mean_absolute_error: 20.1995 - val_loss: 26.4233 - val_mean_absolute_error: 26.4233
# Epoch 35/50
# 3359/3359 [==============================] - 0s 17us/step - loss: 17.2910 - mean_absolute_error: 17.2910 - val_loss: 27.2541 - val_mean_absolute_error: 27.2541
# Epoch 36/50
# 3359/3359 [==============================] - 0s 17us/step - loss: 15.2720 - mean_absolute_error: 15.2720 - val_loss: 28.2262 - val_mean_absolute_error: 28.2262
# Epoch 37/50
# 3359/3359 [==============================] - 0s 19us/step - loss: 15.3194 - mean_absolute_error: 15.3194 - val_loss: 30.8355 - val_mean_absolute_error: 30.8355
# Epoch 38/50
# 3359/3359 [==============================] - 0s 18us/step - loss: 19.0409 - mean_absolute_error: 19.0409 - val_loss: 31.3939 - val_mean_absolute_error: 31.3939
# Epoch 39/50
# 3359/3359 [==============================] - 0s 17us/step - loss: 17.3309 - mean_absolute_error: 17.3309 - val_loss: 33.5929 - val_mean_absolute_error: 33.5929
# Epoch 40/50
# 3359/3359 [==============================] - 0s 18us/step - loss: 14.1634 - mean_absolute_error: 14.1634 - val_loss: 32.1101 - val_mean_absolute_error: 32.1101
# Epoch 41/50
# 3359/3359 [==============================] - 0s 18us/step - loss: 14.5772 - mean_absolute_error: 14.5772 - val_loss: 29.2320 - val_mean_absolute_error: 29.2320
# Epoch 42/50
# 3359/3359 [==============================] - 0s 17us/step - loss: 15.7724 - mean_absolute_error: 15.7724 - val_loss: 28.7057 - val_mean_absolute_error: 28.7057
# Epoch 43/50
# 3359/3359 [==============================] - 0s 18us/step - loss: 14.3308 - mean_absolute_error: 14.3308 - val_loss: 28.2914 - val_mean_absolute_error: 28.2914
# Epoch 44/50
# 3359/3359 [==============================] - 0s 17us/step - loss: 16.2203 - mean_absolute_error: 16.2203 - val_loss: 33.1289 - val_mean_absolute_error: 33.1289
# Epoch 45/50
# 3359/3359 [==============================] - 0s 18us/step - loss: 18.8326 - mean_absolute_error: 18.8326 - val_loss: 31.2411 - val_mean_absolute_error: 31.2411
# Epoch 46/50
# 3359/3359 [==============================] - 0s 18us/step - loss: 14.5147 - mean_absolute_error: 14.5147 - val_loss: 34.5316 - val_mean_absolute_error: 34.5316
# Epoch 47/50
# 3359/3359 [==============================] - 0s 18us/step - loss: 17.8800 - mean_absolute_error: 17.8800 - val_loss: 44.5803 - val_mean_absolute_error: 44.5803
# Epoch 48/50
# 3359/3359 [==============================] - 0s 18us/step - loss: 18.0883 - mean_absolute_error: 18.0883 - val_loss: 36.0729 - val_mean_absolute_error: 36.0729
# Epoch 49/50
# 3359/3359 [==============================] - 0s 17us/step - loss: 18.3624 - mean_absolute_error: 18.3624 - val_loss: 32.7475 - val_mean_absolute_error: 32.7475
# Epoch 50/50
# 3359/3359 [==============================] - 0s 18us/step - loss: 21.5654 - mean_absolute_error: 21.5654 - val_loss: 33.6366 - val_mean_absolute_error: 33.6366

# %%
print(history.history.keys())
plt.plot(History.history['mean_absolute_error'])
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_error', 'loss', 'mean_absolute_error'])
# Text(0.5, 0, 'epoch')

# %%
plt.plot(History.history['mean_absolute_error'])
plt.plot(History.history['val_mean_absolute_error'])
plt.title('mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
 # summarize history for loss
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# #**Case study : Crop Counting**

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import to_categorical
from keras.preprocessing import image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tqdm import tqdm
# %matplotlib inline

# %%
train = pd.read_csv('/content/drive/My Drive/Bennet/number_final.csv')    # reading the csv file
train.head()      # printing first five rows of the file
# Out:
#    ID   no
# 0   0   36
# 1   1   58
# 2   2   94
# 3   3  157
# 4   4   46

# %%
train.columns
# Out:
# Index(['ID', 'no'], dtype='object')

# %%
train.shape
# Out:
# (10, 2)

# %%
import glob
filelist = glob.glob('/content/drive/My Drive/Bennet/images/*.jpg')
filelist
# Out:
# ['/content/drive/My Drive/Bennet/images/4.jpg',
#  '/content/drive/My Drive/Bennet/images/7.jpg',
#  '/content/drive/My Drive/Bennet/images/8.jpg',
#  '/content/drive/My Drive/Bennet/images/0.jpg',
#  '/content/drive/My Drive/Bennet/images/1.jpg',
#  '/content/drive/My Drive/Bennet/images/5.jpg',
#  '/content/drive/My Drive/Bennet/images/2.jpg',
#  '/content/drive/My Drive/Bennet/images/3.jpg',
#  '/content/drive/My Drive/Bennet/images/6.jpg',
#  '/content/drive/My Drive/Bennet/images/9.jpg']

# %%
train_image = []

# %%
img = image.load_img('/content/drive/My Drive/Bennet/images/0.jpg',target_size=(400,400,3))
img = image.img_to_array(img)
img = img/255
train_image.append(img)

# %%
img = image.load_img('/content/drive/My Drive/Bennet/images/1.jpg',target_size=(400,400,3))
img = image.img_to_array(img)
img = img/255
train_image.append(img)

# %%
img = image.load_img('/content/drive/My Drive/Bennet/images/2.jpg',target_size=(400,400,3))
img = image.img_to_array(img)
img = img/255
train_image.append(img)

# %%
img = image.load_img('/content/drive/My Drive/Bennet/images/3.jpg',target_size=(400,400,3))
img = image.img_to_array(img)
img = img/255
train_image.append(img)

# %%
img = image.load_img('/content/drive/My Drive/Bennet/images/4.jpg',target_size=(400,400,3))
img = image.img_to_array(img)
img = img/255
train_image.append(img)

# %%
img = image.load_img('/content/drive/My Drive/Bennet/images/5.jpg',target_size=(400,400,3))
img = image.img_to_array(img)
img = img/255
train_image.append(img)

# %%
img = image.load_img('/content/drive/My Drive/Bennet/images/6.jpg',target_size=(400,400,3))
img = image.img_to_array(img)
img = img/255
train_image.append(img)

# %%
img = image.load_img('/content/drive/My Drive/Bennet/images/7.jpg',target_size=(400,400,3))
img = image.img_to_array(img)
img = img/255
train_image.append(img)

# %%
img = image.load_img('/content/drive/My Drive/Bennet/images/8.jpg',target_size=(400,400,3))
img = image.img_to_array(img)
img = img/255
train_image.append(img)

# %%
img = image.load_img('/content/drive/My Drive/Bennet/images/9.jpg',target_size=(400,400,3))
img = image.img_to_array(img)
img = img/255
train_image.append(img)

# %%
X = np.array(train_image)

# %%
X.shape
# Out:
# (10, 400, 400, 3)

# %%
plt.imshow(X[2])

# %%
train['no'][2]
# Out:
# 94

# %%
y = np.array(train.drop(['ID'],axis=1))
y.shape
# Out:
# (10, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

# %%
model = Sequential()

model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape = (400,400,3)))
model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu'))
model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu'))
model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

model.add(Flatten())
model.add(Dense(64, kernel_initializer='normal', activation='relu'))

model.add(Dropout(0.25))
model.add(Dense(64, kernel_initializer='normal', activation='relu'))

model.add(Dropout(0.25))
model.add(Dense(64, kernel_initializer='normal', activation='relu'))

model.add(Dense(1, activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_43 (Conv2D)           (None, 398, 398, 32)      896
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 396, 396, 32)      9248
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 198, 198, 32)      0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 196, 196, 32)      9248
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 194, 194, 32)      9248
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 97, 97, 32)        0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 95, 95, 32)        9248
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 93, 93, 32)        9248
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 46, 46, 32)        0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 67712)             0
# _________________________________________________________________
# dense_15 (Dense)             (None, 64)                4333632
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_16 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 4,389,153
# Trainable params: 4,389,153
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss='mean_squared_error', metrics=['mean_absolute_error'])

# %%
from keras.callbacks import History
history = History()
history = model.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test), verbose=True)
# Out:
# Train on 8 samples, validate on 2 samples
# Epoch 1/50
# 8/8 [==============================] - 2s 242ms/step - loss: 493.2541 - mean_absolute_error: 18.8226 - val_loss: 560.0835 - val_mean_absolute_error: 16.9895
# Epoch 2/50
# 8/8 [==============================] - 0s 23ms/step - loss: 2700.8657 - mean_absolute_error: 45.4412 - val_loss: 279.0172 - val_mean_absolute_error: 14.6845
# Epoch 3/50
# 8/8 [==============================] - 0s 21ms/step - loss: 877.6073 - mean_absolute_error: 26.9160 - val_loss: 342.8274 - val_mean_absolute_error: 15.8673
# Epoch 4/50
# 8/8 [==============================] - 0s 20ms/step - loss: 629.2876 - mean_absolute_error: 19.9056 - val_loss: 715.7715 - val_mean_absolute_error: 25.6671
# Epoch 5/50
# 8/8 [==============================] - 0s 19ms/step - loss: 575.8782 - mean_absolute_error: 22.2541 - val_loss: 369.3440 - val_mean_absolute_error: 16.6747
# Epoch 6/50
# 8/8 [==============================] - 0s 19ms/step - loss: 438.9362 - mean_absolute_error: 16.6673 - val_loss: 166.4277 - val_mean_absolute_error: 12.6247
# Epoch 7/50
# 8/8 [==============================] - 0s 19ms/step - loss: 254.1842 - mean_absolute_error: 12.3640 - val_loss: 200.2937 - val_mean_absolute_error: 13.8526
# Epoch 8/50
# 8/8 [==============================] - 0s 19ms/step - loss: 436.1450 - mean_absolute_error: 17.6503 - val_loss: 199.0273 - val_mean_absolute_error: 13.8434
# Epoch 9/50
# 8/8 [==============================] - 0s 18ms/step - loss: 536.6714 - mean_absolute_error: 21.6305 - val_loss: 169.9565 - val_mean_absolute_error: 12.7415
# Epoch 10/50
# 8/8 [==============================] - 0s 19ms/step - loss: 194.9959 - mean_absolute_error: 11.0700 - val_loss: 251.9469 - val_mean_absolute_error: 11.4575
# Epoch 11/50
# 8/8 [==============================] - 0s 18ms/step - loss: 123.3830 - mean_absolute_error: 8.7272 - val_loss: 483.2649 - val_mean_absolute_error: 19.9255
# Epoch 12/50
# 8/8 [==============================] - 0s 18ms/step - loss: 638.5731 - mean_absolute_error: 19.7732 - val_loss: 364.3878 - val_mean_absolute_error: 16.1813
# Epoch 13/50
# 8/8 [==============================] - 0s 19ms/step - loss: 330.5492 - mean_absolute_error: 14.2180 - val_loss: 211.5741 - val_mean_absolute_error: 11.7399
# Epoch 14/50
# 8/8 [==============================] - 0s 19ms/step - loss: 183.2633 - mean_absolute_error: 12.0780 - val_loss: 176.9797 - val_mean_absolute_error: 13.0246
# Epoch 15/50
# 8/8 [==============================] - 0s 19ms/step - loss: 341.7670 - mean_absolute_error: 16.0780 - val_loss: 180.1200 - val_mean_absolute_error: 13.3484
# Epoch 16/50
# 8/8 [==============================] - 0s 19ms/step - loss: 193.8113 - mean_absolute_error: 11.5026 - val_loss: 180.5743 - val_mean_absolute_error: 13.1500
# Epoch 17/50
# 8/8 [==============================] - 0s 19ms/step - loss: 540.8558 - mean_absolute_error: 19.2510 - val_loss: 219.5445 - val_mean_absolute_error: 12.0560
# Epoch 18/50
# 8/8 [==============================] - 0s 19ms/step - loss: 272.9343 - mean_absolute_error: 13.9826 - val_loss: 459.5049 - val_mean_absolute_error: 18.9163
# Epoch 19/50
# 8/8 [==============================] - 0s 19ms/step - loss: 738.8123 - mean_absolute_error: 20.0628 - val_loss: 439.1516 - val_mean_absolute_error: 18.2512
# Epoch 20/50
# 8/8 [==============================] - 0s 19ms/step - loss: 442.1847 - mean_absolute_error: 17.5737 - val_loss: 281.3408 - val_mean_absolute_error: 12.1202
# Epoch 21/50
# 8/8 [==============================] - 0s 18ms/step - loss: 271.9514 - mean_absolute_error: 11.2526 - val_loss: 192.5333 - val_mean_absolute_error: 13.1727
# Epoch 22/50
# 8/8 [==============================] - 0s 18ms/step - loss: 124.2664 - mean_absolute_error: 9.1884 - val_loss: 199.2314 - val_mean_absolute_error: 14.1120
# Epoch 23/50
# 8/8 [==============================] - 0s 19ms/step - loss: 829.1544 - mean_absolute_error: 20.2795 - val_loss: 203.6101 - val_mean_absolute_error: 14.2493
# Epoch 24/50
# 8/8 [==============================] - 0s 19ms/step - loss: 1063.5453 - mean_absolute_error: 24.1904 - val_loss: 194.0926 - val_mean_absolute_error: 13.7269
# Epoch 25/50
# 8/8 [==============================] - 0s 19ms/step - loss: 806.1244 - mean_absolute_error: 21.9931 - val_loss: 247.6993 - val_mean_absolute_error: 12.4324
# Epoch 26/50
# 8/8 [==============================] - 0s 19ms/step - loss: 206.2415 - mean_absolute_error: 13.1597 - val_loss: 452.9264 - val_mean_absolute_error: 18.3123
# Epoch 27/50
# 8/8 [==============================] - 0s 19ms/step - loss: 185.6478 - mean_absolute_error: 10.9310 - val_loss: 654.4938 - val_mean_absolute_error: 23.5858
# Epoch 28/50
# 8/8 [==============================] - 0s 18ms/step - loss: 388.4431 - mean_absolute_error: 19.4540 - val_loss: 649.1996 - val_mean_absolute_error: 23.4414
# Epoch 29/50
# 8/8 [==============================] - 0s 19ms/step - loss: 777.2223 - mean_absolute_error: 23.1156 - val_loss: 388.6570 - val_mean_absolute_error: 16.1254
# Epoch 30/50
# 8/8 [==============================] - 0s 18ms/step - loss: 106.9015 - mean_absolute_error: 9.0928 - val_loss: 258.9888 - val_mean_absolute_error: 12.3609
# Epoch 31/50
# 8/8 [==============================] - 0s 18ms/step - loss: 519.3365 - mean_absolute_error: 17.5735 - val_loss: 196.5438 - val_mean_absolute_error: 13.6920
# Epoch 32/50
# 8/8 [==============================] - 0s 18ms/step - loss: 231.3560 - mean_absolute_error: 12.9596 - val_loss: 204.8149 - val_mean_absolute_error: 14.3041
# Epoch 33/50
# 8/8 [==============================] - 0s 18ms/step - loss: 412.2891 - mean_absolute_error: 16.9159 - val_loss: 205.1629 - val_mean_absolute_error: 14.3183
# Epoch 34/50
# 8/8 [==============================] - 0s 19ms/step - loss: 326.1732 - mean_absolute_error: 14.9176 - val_loss: 198.1458 - val_mean_absolute_error: 13.9382
# Epoch 35/50
# 8/8 [==============================] - 0s 18ms/step - loss: 638.7191 - mean_absolute_error: 20.5084 - val_loss: 230.8185 - val_mean_absolute_error: 12.8815
# Epoch 36/50
# 8/8 [==============================] - 0s 19ms/step - loss: 180.7300 - mean_absolute_error: 8.5207 - val_loss: 407.0864 - val_mean_absolute_error: 16.6628
# Epoch 37/50
# 8/8 [==============================] - 0s 19ms/step - loss: 263.3030 - mean_absolute_error: 13.8141 - val_loss: 586.4946 - val_mean_absolute_error: 21.8345
# Epoch 38/50
# 8/8 [==============================] - 0s 18ms/step - loss: 556.8871 - mean_absolute_error: 20.3916 - val_loss: 492.3906 - val_mean_absolute_error: 19.3031
# Epoch 39/50
# 8/8 [==============================] - 0s 18ms/step - loss: 184.9311 - mean_absolute_error: 12.1692 - val_loss: 340.7259 - val_mean_absolute_error: 14.1370
# Epoch 40/50
# 8/8 [==============================] - 0s 19ms/step - loss: 418.5509 - mean_absolute_error: 13.0111 - val_loss: 224.1507 - val_mean_absolute_error: 13.0982
# Epoch 41/50
# 8/8 [==============================] - 0s 19ms/step - loss: 385.4274 - mean_absolute_error: 15.9481 - val_loss: 200.8243 - val_mean_absolute_error: 14.0384
# Epoch 42/50
# 8/8 [==============================] - 0s 19ms/step - loss: 495.8304 - mean_absolute_error: 18.7215 - val_loss: 204.1960 - val_mean_absolute_error: 14.2713
# Epoch 43/50
# 8/8 [==============================] - 0s 18ms/step - loss: 662.3348 - mean_absolute_error: 22.0362 - val_loss: 202.7114 - val_mean_absolute_error: 13.9727
# Epoch 44/50
# 8/8 [==============================] - 0s 19ms/step - loss: 569.3445 - mean_absolute_error: 19.2320 - val_loss: 234.6423 - val_mean_absolute_error: 13.1505
# Epoch 45/50
# 8/8 [==============================] - 0s 18ms/step - loss: 127.1258 - mean_absolute_error: 8.6437 - val_loss: 367.5715 - val_mean_absolute_error: 14.9584
# Epoch 46/50
# 8/8 [==============================] - 0s 19ms/step - loss: 29.2792 - mean_absolute_error: 4.2441 - val_loss: 568.4023 - val_mean_absolute_error: 21.1683
# Epoch 47/50
# 8/8 [==============================] - 0s 18ms/step - loss: 416.7015 - mean_absolute_error: 14.6352 - val_loss: 606.8556 - val_mean_absolute_error: 22.1048
# Epoch 48/50
# 8/8 [==============================] - 0s 18ms/step - loss: 345.5538 - mean_absolute_error: 14.4867 - val_loss: 458.9942 - val_mean_absolute_error: 17.9950
# Epoch 49/50
# 8/8 [==============================] - 0s 18ms/step - loss: 247.7911 - mean_absolute_error: 11.8896 - val_loss: 283.2195 - val_mean_absolute_error: 12.8939
# Epoch 50/50
# 8/8 [==============================] - 0s 18ms/step - loss: 145.0402 - mean_absolute_error: 9.9746 - val_loss: 221.3511 - val_mean_absolute_error: 13.7712

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
 # summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model mean squared error')
plt.ylabel('mean_squared_error')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
